# %%
from IPython.display import clear_output

# %%
class Student():
  def __init__(self):
    self.id = int(input("Enter your id : " )) 
    self.name = input("Enter your name : ")
    self.email =input("Enter the email : ")
    self.password=input("Enter the password : ")
    self.courses = []
    number_of_courses = int(input("Enter the number of courses : "))
    
    for i in range(number_of_courses):
      Course_ID = int(input(f"Enter the course {i+1} id : "))
      for course in courses_list:
        if course.id == Course_ID:
          self.courses.append(course)

  def get_all(self):
    print(str(self.id),end="\t")
    print(self.name,end="\t\t")
    print(self.email,end="\t\t")
    print(self.password,end="\n\t\t")

# %%
class courses():
  def __init__(self):
    self.id = int(input("Enter id : "))
    self.name = input("Enter name : ")
    self.price = input("Enter price : ")
    self.author_id = int(input("Enter author_id : "))

  def get_all(self):
    print(str(self.id),end="\t")
    print(self.name,end="\t")
    print(self.price,end="\t")
    print(self.author_id,end="\n\t")

# %%
class Author():
  def __init__ (self):
   self.id = int(input("Enter Author id : "))
   self.name = input("Enter Author name : ")

  def get_all(self):
    print(str(self.id),end="\t\t")
    print(self.name,end="\n\t")

# %%
class student_courses():
  def __init__(self):
    self.student_id = int(input("Enter the student id : "))

  def show_courses(self):
    for student in students_list:
      if student.id == self.student_id:
        for course in student.courses:
          print(course.name)

# %%
students_list = []
courses_list = []
authors_list = []

ans =1
while True:
    print ("""
    1-course
    2-student
    3-author
    4.Exit/Quit
    """)
    ans = int(input("Please enter your choose : ") )
    if ans == 1: 
            course = 1
            while True:
                print ("""
                Course:
                    1- Get all Courses
                    2- Get single Course with id 
                    3- Add Course
                    4- Return to main menu
                """)

                course = int(input("Please enter your choise : ") )
                if  course == 1: 
                  print("\n\tID\tName\tPrice\tAuthor_id",end="\n\t")
                  for i in courses_list:
                    i.get_all()

                elif  course == 2:
                  x=int(input("Enter cousre id : "))

                  print("\n\tID\tName\tPrice\tAuthor_id",end="\n\t")
                  for i in courses_list:
                    if i.id == x:
                      i.get_all()

                elif  course == 3:
                   courses_list.append(courses())
                   clear_output()
                   print("The Course Added")

                elif course == 4:
                  ans = 0
                  clear_output() 
                  break

                else :
                  print("\n Not Valid Choice Try again")

    elif ans == 2:
            student = 1
            while True:
                print ("""
                Student:
                    1-get all Students 
                    2-get single Student with id 
                    3-add Student
                    4-show student courses
                    5-return to main menu
                """)

                student = int(input("Please enter your choise : ") )
                if student == 1: 
                   print("\n\tID\tName\t\tEmail\t\tPassword",end="\n\t")
                   for i in students_list:
                    i.get_all()

                elif  student == 2:
                  x = int(input("Enter student id : "))
                  print("\n\tID\t\tName\t\tEmail\t\tPassword",end="\n\t")
                  for i in students_list:
                    if i.id == x:
                      i.get_all() 

                elif  student == 3:
                  students_list.append(Student())
                  clear_output()
                  print("The Student Added \n")

                elif  student == 4:
                  S = student_courses()
                  S.show_courses()
                
                elif student == 5:
                  clear_output() 
                  ans = 0 
                  break
                  
                else :
                  print("\n Not Valid Choice Try again")


    elif ans == 3:
            author = 1
            while True:
                print ("""
                Author:
                    1-get all Authors 
                    2-get single Author with id 
                    3-add Author
                    4-show author courses
                    5-return to main menu
                """)

                author = int(input("please enter your choise : ") )

                if  author == 1: 
                   print("\n\tID\t\tName",end="\n\t")
                   for i in authors_list:
                    i.get_all() 

                elif author == 2:
                  x=int(input("enter author id : "))
                  print("\n\tID\t\tName",end="\n\t")
                  for i in authors_list:
                    if i.id == x:
                      i.get_all()

                elif author == 3:
                  authors_list.append(Author())
                  clear_output()
                  print("The Author Added \n")

                elif author == 4:
                  x = int(input("enter author id : "))
                  for i in courses_list:
                    if i.author_id == x:
                      print(i.name) 

                elif author == 5:
                  clear_output()
                  ans = 0 
                  break

                else :
                  print("\n Not Valid Choice Try again")

                 

    elif ans == 4:
      clear_output()
      break

    else :
      print("\n Not Valid Choice Try again")
